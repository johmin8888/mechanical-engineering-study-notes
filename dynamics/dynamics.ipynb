# %% [markdown]
# ---
# # 동역학 (Dynamics)
# ---

# %% [markdown]
# ## 관련 영문 과목 및 하위 주제

# %% [markdown]
# - EN PH 131: Mechanics
#     - Kinetics of Particle
#     - Particle Kinetics: Work and Energy
#     - Particle Kinetics: Linear Impulse and Momentum
#     - Planar Motion of A Rigid Body
# - MEC E 250: Engineering Mechanics II
#     - Planar Kinematics
#     - Planar Kinetics: Force and Acceleration
#     - Planar Kinetics: Work and Energy
#     - Planar Kinetics: Impulse and Momentum
#     - Vibrations
# - MEC E 362: Mechanics of Machines
#     - Gears
#     - Relative Motion Analysis
#     - Loop Closure Equations
#     - Force Analysis and Balancing
#     - Multiple Cylinder Engines
#     - Rate of Work Principle
# - MEC E 451: Vibrations and Sound
#     - Single Degree of Freedom Systems
#     - Damped SDOF Systems
#     - Forced SDOF Systems
#     - Forced/Damped SDOF Systems
#     - Transient Analysis
#     - MDOF Systems
#     - Continuous Systems
#     - Acoustics and Noise Control

# %% [markdown]
# ## 목차
